# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Extracting the atronauts CSV into a DataFrame
astronauts_csv = "Resources/astronauts.csv"
astronauts_df = pd.read_csv(astronauts_csv, sep=',', encoding='gbk')
astronauts_df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active    5/17/67  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired     3/7/36   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired     3/3/46     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired    5/20/51  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired    1/20/30  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
#Extracting the science missions CSV into a DataFrame
missions_csv = "Resources/science_missions.csv"
missions_df = pd.read_csv(missions_csv, sep=',', encoding='gbk')
missions_df.head(50)
# Out:
#                     Mission                                    Missuon URL  \
# 0                  ACRIMSAT     https://science.nasa.gov/missions/acrimsat
# 1               ACT-America  https://science.nasa.gov/missions/act-america
# 2                     ADEOS        https://science.nasa.gov/missions/adeos
# 3                   AirMOSS      https://science.nasa.gov/missions/airmoss
# 4                      Aqua         https://science.nasa.gov/missions/aqua
# 5                  Aquarius     https://science.nasa.gov/missions/aquarius
# 6                   ASCENDS      https://science.nasa.gov/missions/ascends
# 7                     ATLAS        https://science.nasa.gov/missions/atlas
# 8                      ATom         https://science.nasa.gov/missions/atom
# 9                       ATS          https://science.nasa.gov/missions/ats
# 10                   ATTREX       https://science.nasa.gov/missions/attrex
# ...

# %%
#creating new data with select columns from the astronauts df
new_astronauts_df = astronauts_df[['Name', 'Birth Date', 'Gender', 'Space Flights', 'Space Walks', 'Missions']].copy()     
new_astronauts_df.head(50)
# Out:
#                       Name Birth Date  Gender  Space Flights  Space Walks  \
# 0          Joseph M. Acaba    5/17/67    Male              2            2
# 1           Loren W. Acton     3/7/36    Male              1            0
# 2         James C. Adamson     3/3/46    Male              2            0
# 3          Thomas D. Akers    5/20/51    Male              4            4
# 4              Buzz Aldrin    1/20/30    Male              2            2
# 5          Andrew M. Allen     8/4/55    Male              3            0
# 6          Joseph P. Allen    6/27/37    Male              2            2
# 7          Scott D. Altman    8/15/59    Male              4            0
# 8        William A. Anders   10/17/33    Male              1            0
# 9      Clayton C. Anderson    2/23/59    Male              2            6
# 10     Michael P. Anderson   12/25/59    Male              2            0
# 11    Dominic A. Antonelli    8/23/67    Male              2            0
# ...
